# %%
import pandas as pd
import numpy as np   #library functions 
import requests
import shutil

df=pd.read_html('https://en.wikipedia.org/wiki/Neha_Bhasin')   #directly getting all tables of website in dataframe
df1=df[0].T                                                     #transposing
print(df1)                                                      
df1.to_csv('df1.csv')
print("*************************")
# Out:
#              0               1                         2                 3  \
# 0  Neha Bhasin  Bhasin in 2019                      Born        Occupation
# 1          NaN             NaN  (age 38)New Delhi, India  Singersongwriter
#
#               4             5          6
# 0  Years active     Spouse(s)     Awards
# 1  2005–present  Sameer Uddin  Full list
# *************************

# %%
df2=df[1]
df2.to_csv('df2.csv')
print(df2)
print("*************************")
# Out:
#        0                                        1  \
# 0   Year                                    Award
# 1   2007                       Vijay TV Awards[5]
# 2   2008                       Filmfare Awards[6]
# 3   2009         Music Mirchi Awards South Awards
# 4   2011                       Stardust Awards[7]
# 5   2011                            Screen Awards
# 6   2011                            Apsara Awards
# 7   2011                          Zee Cine Awards
# 8   2011                   People's Choice Awards
# 9   2011                    Filmfare Awards South
# 10  2011                    Filmfare Awards South
# 11  2011                Music Mirchi Awards South
# 12  2011                   Mirchi Music Awards[8]
# 13  2014           Gama Tollywood Music Awards[9]
# 14  2014  South Indian International Movie Awards
# 15  2016                      Stardust Awards[10]
# 16  2016                  Mirchi Music Awards[11]
# 17  2017                          Filmfare Awards
# ...

# %%
df3=df[2]
df3.to_csv('df3.csv')
print(df3)
print("*************************")
# Out:
#                                   0                             1  \
# 0                              Year                          Song
# 1                              2005         "Bullet – Ek Dhamaka"
# 2                              2006             "Ek Look Ek Look"
# 3                              2007  "I Wanna Rock Like Mummy Ji"
# 4                   "Kudiye Pataka"                           NaN
# 5               "Jashna Di Raat Ha"                           NaN
# 6             "Pesugiren Pesugiren"               Satham Podathey
# 7                 "Sei Yethaavathu"                         Billa
# 8                              2008                 "Hari Puttar"
# 9                      "Kuchh Khaas                       Fashion
# 10             "Kuch Khaas (Remix)"                           NaN
# 11                             2009               "Om Shanthi Om"
# 12            "Atu Nuvve Itu Nuvve"                       Current
# ...

# %%
url='https://upload.wikimedia.org/wikipedia/commons/4/45/Neha_Bhasin_2019.jpg'
im=requests.get(url,stream='True')
path=open('new.png','wb')
shutil.copyfileobj(im.raw,path)
