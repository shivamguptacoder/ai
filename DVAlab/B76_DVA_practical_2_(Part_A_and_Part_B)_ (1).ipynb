# %% [markdown]
# # Aim: Data Visualization and preprocessing on the given data set in Python.

# %% [markdown]
# **PART (A): Data Visualization using Matplotlib**

# %% [markdown]
# Write a program to visualize Company Sales Data &amp; perform the following task
# (CSV file will be provided)

# %%
# Importing the csv file into the dataframe
import pandas as pd
df = pd.read_csv('B_76_ShivamGupta - company_sales_data.csv')
print(df.to_string()) 

# INTERPRETATION
# THE FOLLOWING DATAFRAME SHOWS THE SALES OF EACH ITEM IN PARTICULAR MONTH
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  moisturizer  total_units  total_profit
# 0              1       2500      1500        5200         9200     1200         1500        21100        211000
# 1              2       2630      1200        5100         6100     2100         1200        18330        183300
# 2              3       2140      1340        4550         9550     3550         1340        22470        224700
# 3              4       3400      1130        5870         8870     1870         1130        22270        222700
# 4              5       3600      1740        4560         7760     1560         1740        20960        209600
# 5              6       2760      1555        4890         7490     1890         1555        20140        201400
# 6              7       2980      1120        4780         8980     1780         1120        29550        295500
# ...

# %%
#1. Read Total profit of all months and show it using a line plot

df.plot(x ='month_number', y='total_profit')

# INTERPRETATION
# THE TOTAL PROFIT WAS MAXIMUM IN 11TH MONTH

# %%
#2. Read all product sales data and show it using a multiline plot

import matplotlib.pyplot as plt

# Plot a simple line chart
plt.plot(df['month_number'], df['facecream'], color='g', label='facecream')
plt.plot(df['month_number'], df['facewash'], color='r', label='facewash')
plt.plot(df['month_number'], df['toothpaste'], color='y', label='toothpaste')
plt.plot(df['month_number'], df['bathingsoap'], color='b', label='bathingsoap')
plt.plot(df['month_number'], df['shampoo'], color='m', label='shampoo')
plt.plot(df['month_number'], df['moisturizer'], color='black', label='moisturizer')


# INTERPRETATION
# THE MAXIMUM SALES  IS OF BATHING SOAP 
# THE MINIMUM SALES IS OF MOISTURIZER
# THE ORDER OF SALES IS   BATHINGSOAP > TOOTHPASTE > FACECREAM > SHAMPOO > MOISTURIZER

# %%
#3. Display the number of units sold per month for each product using multiline plots. (i.e.,Separate Plotline for each product).

import matplotlib.pyplot as plt

# Plot a simple line chart
plt.plot(df['month_number'], df['facecream'], color='g', label='facecream',marker='o')
plt.plot(df['month_number'], df['facewash'], color='r', label='facewash',marker='o')
plt.plot(df['month_number'], df['toothpaste'], color='y', label='toothpaste',marker='o')
plt.plot(df['month_number'], df['bathingsoap'], color='b', label='bathingsoap',marker='o')
plt.plot(df['month_number'], df['shampoo'], color='m', label='shampoo',marker='o')
plt.plot(df['month_number'], df['moisturizer'], color='black', label='moisturizer',marker='o')
plt.legend(loc='upper right')
plt.show()

# INTERPRETATION
# THE MAXIMUM SALES  IS OF BATHING SOAP 
# THE MINIMUM SALES IS OF MOISTURIZER
# THE ORDER OF SALES IS   BATHINGSOAP > TOOTHPASTE > FACECREAM > SHAMPOO > MOISTURIZER = FACEWASH
# THERE WAS DROP IN SALES OF BATHING SOAP IN 2ND MONTH 
# THERE WAS A HIKE IN SALES OF SHAMPOO IN 3RD MONTH

# %%
#4. Read toothpaste sales data of each month and show it using a scatter plot.

monthList  = df ['month_number'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
plt.scatter(monthList, toothPasteSalesData, label = 'Tooth paste Sales data')
plt.show()

# INTERPRETATION
# THE MAXIUM SALES OD TOOTHPASTE WAS IN MONTH 10 
# THE MINIMUM SALES OF TOOTHPASTE WAS IN MONTH 3
# THERE IS A SUDDEN INCREASE IN SALES FROM MONTH 10

# %%
#5. Read face cream and facewash product sales data and show it using the bar chart.

monthList  = df ['month_number'].tolist()
faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()

plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream ', color='r',align='edge')
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'Face Wash ', color='y',align='edge')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper right')
plt.title(' Sales data')
plt.title('Facewash and facecream sales data')
plt.show()
 
# INTERPRETATION
# THE GRAPH SHOWS COMPARISON OF FAXCEWASH AND FACECREAM 
# FACECREAN HAS RECORDED NEARLY 2 TIMES THE SALES OF FACEWASH IN MONTHS 1,2,3,4,5,6,7,8,9,12
# FACEWASH AND FACECREAM SALES ARE NEARLY EQUAL IN MONTHS 10,11

# %%
#6. Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk

monthList  = df ['month_number'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
plt.bar(monthList, bathingsoapSalesData)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.title(' Sales data')
plt.title('Bathingsoap sales data')
plt.savefig('D:\new.png', dpi=150)
plt.show()
#path=/content/sample_data

# INTERPRETATION
# BATHING SOAP HAS HIGHEST SALES IN 12TH MONTH
# BATHING SOAP HAS LOWEST SALES IN 2ND MONTH

# %%
#7 Read the total profit of each month and show it using the histogram to see the most common profit ranges
import matplotlib.pyplot as plt

profitList = df ['total_profit'].tolist()
labels = ['low', 'average', 'Good', 'Best']
profit_range = [150000, 175000, 200000, 225000, 250000, 300000, 350000]
profit_dollar=[0,1,2,3,4,5]
plt.hist(profitList, profit_range, label = 'Profit data', color="b")
plt.xlabel('profit range in dollar')
plt.ylabel('Profit(dollar)')
plt.legend(loc='upper left')
plt.xticks(profit_range, color="BLACK")
plt.yticks(profit_dollar, color="BLACK")
plt.title('Profit data')
plt.show()

# INTERPRETATION
# THE MOST COMMON TOTAL PROFIT RANGES BETWEEN 200000 TO 225000

# %%
#8. Calculate total sale data for last year for each product and show it using a Pie chart.

monthList  = df ['month_number'].tolist()
myexplode = [0, 0, 0, 0, 0, 0.2]
mycolor = np.array(["red","springgreen","paleturquoise","yellow","slategrey", "cyan"])

labels = ['FaceWash', 'FaceCream', 'ToothPaste', 'Shampoo', 'Moisturizer', 'Bathing soap']
salesData   = [df ['facewash'].sum(), df ['facecream'].sum(),  df ['toothpaste'].sum(), df ['shampoo'].sum(),
               df ['moisturizer'].sum(), df ['bathingsoap'].sum()]
plt.axis("equal")
plt.pie(salesData, labels=labels,colors=mycolor, autopct='%1.1f%%', explode = myexplode, shadow = True)
plt.legend(loc='lower right')
plt.title('Sales data')
plt.show()

# INTERPRETATION
# THE MAXIMUM SALES WAS OF BATHING SOAP WHICH ACQUIRED AROUND 40 PERCENT OF TOTAL PRODUCT SALES
# THE FACEWASH AND MOISTURIZER WERE THE MINIMUM SALES OF AROUND 6.6 PERCENT EACH

# %%
#9. Read Bathing soap facewash of all months and display it using the Subplot

monthList  = df ['month_number'].tolist()
bathingsoap   = df ['bathingsoap'].tolist()
faceWashSalesData   = df ['facewash'].tolist()

f, axarr = plt.subplots(2, sharex=True)
axarr[0].plot(monthList, bathingsoap, label = 'Bathingsoap Sales Data', color='k', marker='o', linewidth=3)
axarr[0].set_title('Sales data of  a Bathingsoap')
axarr[1].plot(monthList, faceWashSalesData, label = 'Face Wash Sales Data', color='b', marker='o', linewidth=3)
axarr[1].set_title('Sales data of  a facewash')

plt.xticks(monthList)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')

plt.show()

# INTERPRETATION
# THIS CHART COMPARES THE SALES OF BATHINGSOAP AND FACEWASH IN EACH MONTH
# THE REQUIRMENT OF BATHING SOAP WAS CONTINUOUS THROUGHOUT THE MONTH WHILE IN CASE OF FACEWASH THERE WERE MANY UPS AND DOWNS IN FACEWASH

# %%
#10. Read all product sales data and show it using the stack plot.

faceCremSalesData   = df ['facecream'].tolist()
faceWashSalesData   = df ['facewash'].tolist()
toothPasteSalesData = df ['toothpaste'].tolist()
bathingsoapSalesData   = df ['bathingsoap'].tolist()
shampooSalesData   = df ['shampoo'].tolist()
moisturizerSalesData = df ['moisturizer'].tolist()

plt.plot([],[],color='m', label='face Cream', linewidth=5)
plt.plot([],[],color='c', label='Face wash', linewidth=5)
plt.plot([],[],color='r', label='Tooth paste', linewidth=5)
plt.plot([],[],color='k', label='Bathing soap', linewidth=5)
plt.plot([],[],color='g', label='Shampoo', linewidth=5)
plt.plot([],[],color='y', label='Moisturizer', linewidth=5)

plt.stackplot(monthList, faceCremSalesData, faceWashSalesData, toothPasteSalesData, 
              bathingsoapSalesData, shampooSalesData, moisturizerSalesData, 
              colors=['maroon','k','springgreen','slategrey','gold','cyan'])

plt.xlabel('Month Number')
plt.ylabel('Sales unints in Number')
plt.title('Product Data')
plt.legend(loc='upper left')
plt.show()

# INTERPRETATION
# THE FOLLOWING STACK PLOT SHOWS ALL THE SALES OF ALL THE PRODUCTS IN ALL THE MONTHS
# THE ORDER IS BATHINGSOAP > TOOTHPASTE > FACECREAM > SHAMPOO > MOISTURIZER = FACEWASH

# %%
#11. Get total profit of all months and show line plot with the following Style properties.

profitList=df['total_profit'].tolist()
monthList=df['month_number'].tolist()
plt.plot(monthList,profitList)
plt.xlabel('Month number')
plt.ylabel('Profit in dollar')
plt.xticks(monthList)
plt.title('Company profit per month')
plt.yticks([100000,200000,300000,400000,500000])
plt.show()


# INTERPRETATION
# THE PLOT SHOWS THE TOTAL PROFIT IN EACH MONTH 
# MAXIMUM WAS RECORDED IN 11TH MONTH

# %%
#12. Generated line plot must include following Style properties:
#  Line Style dotted and Line-color should be red
#  Show legend at the lower right location.
#  X label name = Month Number
#  Y label name = Sold unit’s number
#  Add a circle marker.
#  Line marker color as red
#  Line width should be 3

profitList=df['total_profit'].tolist()
monthList=df['month_number'].tolist()
plt.plot(monthList,profitList,label='Profit data of lastyear',color='r',marker='o',markerfacecolor='k',linestyle='--',linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Profit in dollar')
plt.legend(loc='lower right')
plt.title('Company Sales data of last year')
plt.xticks(monthList)
plt.yticks([100000,200000,300000,400000,500000])
plt.show()


# INTERPRETATION
# THE PLOT SHOWS THE TOTAL PROFIT IN EACH MONTH 
# MAXIMUM WAS RECORDED IN 11TH MONTH

# %% [markdown]
# **Do as directed part 2:**

# %%
#1. Draw a scatter graph of any 50 random values of x and y axis.



import math
import random
import matplotlib.pyplot as plt
# create random data
no_of_balls = 25
x = [random.triangular() for i in range(no_of_balls)]
y = [random.gauss(0.5, 0.25) for i in range(no_of_balls)]
colors = [random.randint(1, 4) for i in range(no_of_balls)]
areas = [math.pi * random.randint(5, 15)**2 for i in range(no_of_balls)]
# draw the plot
plt.figure()
plt.scatter(x, y, s=areas, c=colors, alpha=0.85)
plt.axis([0.0, 1.0, 0.0, 1.0])
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# INTERPRETATION
# THIS IS A RANDOM SCATTER PLOT OF 50 POINTS.
# THE DENSITY IS HGHEST AT 0.5

# %%
#2. Create data using numpy array from 0 to 5 with a gap of 0.01 for x axis, consider y axis
#   as square values of x and show the line graph with grid lines

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.01)
y = np.square(x)

plt.title("x vs x^2")
plt.xlabel("x values")
plt.ylabel("x sq values")

plt.plot(x, y)
plt.grid()
plt.show()

# INTERPRETATION
# THE FOLLOWING LINE GRAPH SHOWS X VS X^2 IS A PARABOLA OPENING UPWARD

# %%
#3. Create linear, square and cube data points and create a multiline graph for the same with title to graph and both axis.

import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 5, 0.01)
y = np.square(x)
z = np.power(x, 3)

plt.title("x vs x2 and x3")
plt.xlabel("x values")

plt.plot(x, y)
plt.plot(x, z)
plt.grid()

plt.show()

# INTERPRETATION
# THE FOLLOWING LINE CHARTS SHOWS 2 LINE GRAPHS 
# 1] X VS X^2
# 2] X VS X^3
# THE GRAPH X^3 IS MORE PARABOLIC THAN X^2

# %%
#4. The dataset given, records data of city temperatures over the years’2014 and 2015. Plot
#   the histogram of the temperatures over this period for the cities of San Francisco and Moscow.

import pandas as pd
import matplotlib.pyplot as plt

df_temp = pd.read_csv("CityTemps.csv")
print(df_temp)

x_mosco = df_temp["Moscow"]
x_san_Francisco = df_temp["San Francisco"]

plt.hist(x_mosco, len(x_mosco), facecolor='blue', alpha=0.5)
plt.hist(x_san_Francisco, len(x_san_Francisco), facecolor='red', alpha=0.5)

plt.xlabel("Temperature")
plt.ylabel("Frequency")
plt.title("Temperatures of Mosco and San Francisco")

plt.setp(plt.gca().get_xticklabels(), rotation=90, horizontalalignment='right') # Rotate Axis Labels

plt.show()

# INTERPRETATION
# This shows the temperature of San Fransisco cities from 2014 to 2015
# Out:
#     Year  Month  Moscow  Melbourne  San Francisco
# 0   2014      1    -8.6       22.0           12.8
# 1   2014      2    -1.9       21.5           12.7
# 2   2014      3     2.8       19.5           15.0
# 3   2014      4     7.0       15.8           15.7
# 4   2014      5    16.0       13.9           17.5
# 5   2014      6    16.1       11.3           17.9
# 6   2014      7    21.1        9.9           19.4
# 7   2014      8    19.2       10.4           19.5
# 8   2014      9    12.3       12.8           20.2
# 9   2014     10     3.7       15.6           20.4
# 10  2014     11    -1.3       17.3           15.4
# 11  2014     12    -3.9       18.9           13.8
# 12  2015      1    -4.4       20.4           12.2
# 13  2015      2    -2.2       21.8           14.8
# 14  2015      3     2.0       17.4           15.7
# 15  2015      4     6.1       14.1           14.8
# 16  2015      5    14.2       12.6           14.7
# 17  2015      6    17.9        9.8           17.1
# ...

# %% [markdown]
# PART (B): Data Preprocessing
# Business challenge/requirement
# Perform data wrangling for student’s data. The data is maintained for subjects: Math, Physics and Data
# Structure. This data is stored in different files. Task is to perform analysis of scores and find if there is
# any correlation of score with age, ethnicity etc.
#
# DO as directed:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 1. Read the three csv files which contains the score of same students in term1 for each Subject


df_math = pd.read_csv("B_76_ShivamGupta - MathScoreTerm1.csv")
df_dss = pd.read_csv("B_76_ShivamGupta - DSScoreTerm1.csv")
df_phy = pd.read_csv("B_76_ShivamGupta - PhysicsScoreTerm1.csv")


print(df_math.head())
print('\n')
print(df_dss.head())
print('\n')
print(df_phy.head())

# INTERPRETATION
# The following shows the first 5 tuples of each dataset  of mathscore Physicsscore and dsscore
# Out:
#              Name  Score  Age         Ethinicity Subject Sex  ID
# 0  AI-KYUNG CHUNG   88.0   18     White American   Maths   M   1
# 1     ALAN HARVEY   85.0   19  European American   Maths   M   2
# 2    ALAN REYNAUD   45.0   19  European American   Maths   M   3
# 3  ALBERT CENDANA   82.0   18     White American   Maths   M   4
# 4  ALBERT HOLT JR   82.0   18     White American   Maths   F   5
#
#
#              Name  Score  Age         Ethinicity        Subject Sex  ID
# 0  AI-KYUNG CHUNG   82.0   18     White American  Data Structue   M   1
# 1     ALAN HARVEY   79.0   19  European American  Data Structue   M   2
# 2    ALAN REYNAUD   39.0   19  European American  Data Structue   M   3
# 3  ALBERT CENDANA   76.0   18     White American  Data Structue   M   4
# 4  ALBERT HOLT JR   76.0   18     White American  Data Structue   F   5
#
#
#              Name  Score  Age         Ethinicity  Subject Sex  ID
# 0  AI-KYUNG CHUNG   84.0   18     White American  Physics   M   1
# ...

# %%
# 2. Remove the name and ethnicity column (to ensure confidentiality)
# Delete Ethinicity
del df_math["Ethinicity"]
del df_dss["Ethinicity"]
del df_phy["Ethinicity"]

# Delete Name
del df_math["Name"]
del df_dss["Name"]
del df_phy["Name"]

print(df_math.head())
print('\n')
print(df_dss.head())
print('\n')
print(df_phy.head())

# INTERPRETATION
# The following shows the first 5 tuples of each dataset  of mathscore Physicsscore and dsscore
# after removing name and ethinicity column
# Out:
#    Score  Age Subject Sex  ID
# 0   88.0   18   Maths   M   1
# 1   85.0   19   Maths   M   2
# 2   45.0   19   Maths   M   3
# 3   82.0   18   Maths   M   4
# 4   82.0   18   Maths   F   5
#
#
#    Score  Age        Subject Sex  ID
# 0   82.0   18  Data Structue   M   1
# 1   79.0   19  Data Structue   M   2
# 2   39.0   19  Data Structue   M   3
# 3   76.0   18  Data Structue   M   4
# 4   76.0   18  Data Structue   F   5
#
#
#    Score  Age  Subject Sex  ID
# 0   84.0   18  Physics   M   1
# 1   81.0   19  Physics   M   2
# 2   41.0   19  Physics   M   3
# 3   78.0   18  Physics   M   4
# 4   78.0   18  Physics   F   5

# %%
# 3. Fill missing score data with zero
df_math.fillna(0)
df_dss.fillna(0)
df_phy.fillna(0)

print(df_math.head())
print('\n')
print(df_dss.head())
print('\n')
print(df_phy.head())

# INTERPRETATION
# This is the Preprocessing of data part where missing data is replaced with zero
# Out:
#    Score  Age Subject Sex  ID
# 0   88.0   18   Maths   M   1
# 1   85.0   19   Maths   M   2
# 2   45.0   19   Maths   M   3
# 3   82.0   18   Maths   M   4
# 4   82.0   18   Maths   F   5
#
#
#    Score  Age        Subject Sex  ID
# 0   82.0   18  Data Structue   M   1
# 1   79.0   19  Data Structue   M   2
# 2   39.0   19  Data Structue   M   3
# 3   76.0   18  Data Structue   M   4
# 4   76.0   18  Data Structue   F   5
#
#
#    Score  Age  Subject Sex  ID
# 0   84.0   18  Physics   M   1
# 1   81.0   19  Physics   M   2
# 2   41.0   19  Physics   M   3
# 3   78.0   18  Physics   M   4
# 4   78.0   18  Physics   F   5

# %%
# 4. Merge the three files
df_merged = df_math.merge(df_dss, on = "ID", suffixes = ('math', 'ds')).merge(df_phy, on = "ID", suffixes = ("ds", "physics"))

merged_df = df_merged.filter(["ID", "Score_math", "Score_ds", "Score", "Age_math", "Sex", "Ethinicity"]).rename(columns={"Score": "Score_physics", "Age_math": "Age"})



# INTERPRETATION
# here we merge 3 files
# Out:
#       ID  Score_physics  Sex
# 0      1           84.0    1
# 1      2           81.0    1
# 2      3           41.0    1
# 3      4           78.0    1
# 4      5           78.0    2
# ..   ...            ...  ...
# 594  595           41.0    2
# 595  596           71.0    1
# 596  597           49.0    1
# 597  598           71.0    1
# 598  599           69.0    1
#
# [599 rows x 3 columns]

# %%
# 5. Change Sex(M/F) Column to 1/2 for further analysis
merged_df["Sex"] = [1 if sex == "M" else 2 for sex in merged_df["Sex"]]

print(merged_df)


# INTERPRETATION
# Here we channge SEX from male to female
# Out:
#       ID  Score_physics  Sex
# 0      1           84.0    2
# 1      2           81.0    2
# 2      3           41.0    2
# 3      4           78.0    2
# 4      5           78.0    2
# ..   ...            ...  ...
# 594  595           41.0    2
# 595  596           71.0    2
# 596  597           49.0    2
# 597  598           71.0    2
# 598  599           69.0    2
#
# [599 rows x 3 columns]

# %%
#6. Store the data in new file –ScoreFinal.csv
merged_df.to_csv("ScoreFinal.csv")


# INTERPRETATION
# merged DF is saved to Scorefinal.csv file

# %%
#7. Convert ethnicity to numerical value

mapping = {"White American" : 1, "European American" : 2, "Hispanic" : 3, "African American" : 4}

merged_df.replace({'Ethinicity' :  mapping})


# INTERPRETATION
# The ethinicity is converted to numerical value
# Out:
#       ID  Score_physics  Sex
# 0      1           84.0    2
# 1      2           81.0    2
# 2      3           41.0    2
# 3      4           78.0    2
# 4      5           78.0    2
# ..   ...            ...  ...
# 594  595           41.0    2
# 595  596           71.0    2
# 596  597           49.0    2
# 597  598           71.0    2
# 598  599           69.0    2
#
# [599 rows x 3 columns]

# %%
#8. Fill the missing score for a student to the average of the class

mean_score = merged_df["Score_physics"].mean()
merged_df['Score_physics'].fillna(merged_df['Score_physics'].mean(), inplace=True)

print(merged_df)

# INTERPRETATION
# We have succesfully filled the missing scores with mean of class
# Out:
#       ID  Score_physics  Sex
# 0      1           84.0    2
# 1      2           81.0    2
# 2      3           41.0    2
# 3      4           78.0    2
# 4      5           78.0    2
# ..   ...            ...  ...
# 594  595           41.0    2
# 595  596           71.0    2
# 596  597           49.0    2
# 597  598           71.0    2
# 598  599           69.0    2
#
# [599 rows x 3 columns]
